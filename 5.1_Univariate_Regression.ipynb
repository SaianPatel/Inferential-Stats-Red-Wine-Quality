# %% [markdown]
# ## 5.1. Univariate Regression

# %%
# Import required modules
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv("Data/winequality-red.csv")

# %% [markdown]
# ### 5.1.1. Fitting the Model

# %% [markdown]
# Fit a linear regression model using a single predictor for a single response.

# %%
# Choose x and y for the regression model
x = df['alcohol'].dropna()
y = df['quality'].dropna()

# Perform regression using linregress
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# Display the results
print("== Alcohol vs. Quality ==")
print("Intercept (estimated): ", intercept)
print("Slope (estimated):", slope)
print("R-squared:", r_value**2)
print("p-value:", p_value)
# Out:
# == Alcohol vs. Quality ==
# Intercept (estimated):  1.8749748870415623
# Slope (estimated): 0.3608417653307738
# R-squared: 0.22673436811123152
# p-value: 2.831476979239677e-91

# %% [markdown]
# Plot the results of the regression.

# %%
# Plot the data and the fitted line
plt.figure(figsize=(12,8))
plt.scatter(x, y, color='blue', label='Data')

# Cretae a sorted x-range for the fitted line
xQ = np.linspace(x.min(), x.max(), 100)
yQ = intercept + slope * xQ

# Plot the line
plt.plot(xQ, yQ, color='red', label='Fitted Line - R^2=0.2267')

# Annotating the figure
plt.xlabel("Alcohol")
plt.ylabel("Quality")
plt.legend()

# %% [markdown]
# ### 5.1.2. CLT Consideration

# %%
sample_sizes = [10, 50, 200, 500]  # Different sample sizes to test
num_iterations = 10000  # Number of random samples per sample size

# Store estimates for each sample size
regression_estimates = {size: {'slopes': [], 'intercepts': [], 'std_errors': []} for size in sample_sizes}

# Perform random sampling and regression
for size in sample_sizes:
    for _ in range(num_iterations):
        sample_indices = np.random.choice(len(x), size=size, replace=True)
        x_sample, y_sample = x.iloc[sample_indices], y.iloc[sample_indices]
        
        # Fit regression model
        slope_sample, intercept_sample, _, _, std_err_sample = linregress(x_sample, y_sample)
        
        # Store estimates
        regression_estimates[size]['slopes'].append(slope_sample)
        regression_estimates[size]['intercepts'].append(intercept_sample)
        regression_estimates[size]['std_errors'].append(std_err_sample)

# %%
# Plot: Superimposed distribution of sample means
plt.figure(figsize=(12, 12))

colors = ['red', 'pink',  'purple', 'blue']
for i, size in enumerate(sample_sizes):
    plt.hist(regression_estimates[size]['slopes'], bins=50, alpha=0.5, density=True, color=colors[i], label=f'n={size}', edgecolor='black')

# Formatting
plt.xlabel("Slope Estimates")
plt.ylabel("Density")
plt.xlim(-1, 1.5)
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %%
# Plot: Superimposed distribution of sample means
plt.figure(figsize=(12, 12))

colors = ['orange', 'green', 'blue', 'pink']
for i, size in enumerate(sample_sizes):
    plt.hist(regression_estimates[size]['std_errors'], bins=50, alpha=0.5, density=True, color=colors[i], label=f'n={size}', edgecolor='black')

# Formatting
plt.xlabel("Standard Error")
plt.ylabel("Density")
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Extract X and Y from the dataset
X = df['alcohol'].values  # Assuming multiple predictors
Y = df['quality'].values.flatten()  # First column as target

# Sample sizes to test
sample_sizes = [10, 50, 200, 500]
# np.logspace(1, 3, num=10, dtype=int)  # Logarithmic spacing from n=10 to n=1000
num_iterations = 10000  # Number of bootstrap iterations per sample size

# Store mean standard errors
mean_standard_errors = []

# Compute standard errors for different sample sizes
for size in sample_sizes:
    standard_errors = []
    for _ in range(num_iterations):
        idx = np.random.choice(len(Y), size=size, replace=True)
        X_sample, Y_sample = X[idx], Y[idx]
        
        X_sample = sm.add_constant(X_sample)  # Add intercept term
        model = sm.OLS(Y_sample, X_sample).fit()
        
        standard_errors.append(model.bse[1])  # Store SE of first coefficient

    mean_standard_errors.append(np.mean(standard_errors))  # Store average SE for each sample size

# Plot: Standard Error vs. Sample Size
plt.figure(figsize=(10, 6))
plt.plot(sample_sizes, mean_standard_errors, marker='o', linestyle='-', color='blue', label="Mean Standard Error")

# Theoretical CLT Relationship: SE ∝ 1/sqrt(n)
plt.plot(sample_sizes, mean_standard_errors[0] * np.sqrt(sample_sizes[0]) / np.sqrt(sample_sizes), 'r--', label="1/√n Trend")

# Formatting
plt.xlabel("Sample Size")
plt.ylabel("Mean Standard Error")
# plt.title("Effect of Sample Size on Standard Error")
# plt.xscale("log")  # Logarithmic scale for better visualization
# plt.yscale("log")
plt.legend()
plt.grid(alpha=0.3)
plt.show()
